# %% [markdown]
# jika menggunakan kode ini hasil kurang maksimal

# %% [markdown]
# # Library untuk melakukan crawling data twiter
# 1. !pip install pandas
# 2. !curl -sL https://deb.nodesource.com/setup_18.x | sudo -E bash - : Perintah untuk mengunduh dan menjalankan script node.js versi 18.x.
# 3. !sudo apt-get install -y nodejs

# %%
# hanya dijalankan sekali saja
# !curl -sL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# 2024-01-28 16:15:17 - Installing pre-requisites
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_18.x nodistro InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 229 kB in 2s (98.1 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# ...

# %% [markdown]
# # Mengambil data twitter menggunakan auth_token
#
# https://twitter.com

# %%
# !pip install npx playwright

# %%
twitter_auth_token = "9438bbd730839e3507bce9bafbb8ee2410b0f0ae"

# %%
filename = 'Data_DebatCapres.csv'
search_keyword = 'debatcapres until:2023-12-15 since:2023-12-14'
limit = 700

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# added 3 packages in 941ms
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_18.x nodistro InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# ...

# %% [markdown]
# # Membaca Dataset hasil crawling twitter

# %%
import pandas as pd

data = pd.read_csv('/content/tweets-data/Data_Prabowo_Bumi.csv')
display(data)
# Out:
#                          created_at               id_str  \
# 0    Sun Jan 21 19:32:39 +0000 2024  1749153051343266005
# 1    Sun Jan 21 15:20:39 +0000 2024  1749089632787353701
# 2    Sun Jan 21 10:16:03 +0000 2024  1749012975082758609
# 3    Sun Jan 21 17:15:53 +0000 2024  1749118633765478819
# 4    Sun Jan 21 13:51:01 +0000 2024  1749067076978069614
# ..                              ...                  ...
# 217  Sun Jan 21 12:40:06 +0000 2024  1749049227542708598
# 218  Sun Jan 21 21:00:10 +0000 2024  1749175076392730725
# 219  Sun Jan 21 11:44:03 +0000 2024  1749035124367540632
# 220  Sun Jan 21 09:23:18 +0000 2024  1748999701083697356
# 221  Sun Jan 21 12:38:34 +0000 2024  1749048842371334161
#
#                                              full_text  quote_count  \
# 0    pak prabowo  tapi tadi debatnya bukan masalah ...          662
# 1    Mencari aktivis yang hilang diculik Prabowo ht...         2571
# 2    Tahun 1999  Tempo mewawancarai Sumitro  ayah P...           84
# ...
