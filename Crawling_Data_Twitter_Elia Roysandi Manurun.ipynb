# %% [markdown]
# # Crawling data sampai 700an twitter
#
# Langkah-langkah yang perlu disiapkan:
# 1. Twitter API: Bisa didapat dengan membuka twitter pribadi dilaptop, searching topik tweet yang pengen kita ambil datanya(yang memiliki tweet yang banyak),  lalu klik kanan dan buka inspect. Setelah itu buka bagian storage, lalu liat bagian cookies. dan buka bagian *auth_token* karena disanalah APInya berada.
# 2. Lalu running semua code dibawah satu persatu.
# 3. catatan sebelum jalanin code dibawah jangan lupa untuk melakukan scrool dahulu ditwitter terkait topik yang kita cari sampai mentok paling bawah, agar data yang diambil juga bisa maksimal dan tidak eror

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
twitter_auth_token = "PASTE_YOUR_API_KEY_HERE"

# %%
# Crawl Data

filename = 'Debat_Capres2.csv' # persiapan file untuk meletakan data
search_keyword = 'debatcapres until:2023-12-16 since:2023-12-14' #debatcapres itu adalah bagian topik yang mau dicari, until itu untuk jangka waktu sampai kapan dan since itu untuk jangka waktu dari kapan?
limit = 700 #total tweet yang dibutuhkan, saran cuman 700 saja maksimalmnya biar tidak error

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# 9438bbd730839e3507bce9bafbb8ee2410b0f0ae
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 778ms
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Tue Dec 12 23:59:56 +0000 2023  1734724800923451539
# 1    Tue Dec 12 23:59:55 +0000 2023  1734724795261206990
# 2    Tue Dec 12 23:59:54 +0000 2023  1734724792446800369
# 3    Tue Dec 12 23:59:44 +0000 2023  1734724751221010884
# 4    Tue Dec 12 23:59:41 +0000 2023  1734724738248069554
# ..                              ...                  ...
# 702  Tue Dec 12 22:33:00 +0000 2023  1734702923945525706
# 703  Tue Dec 12 22:32:35 +0000 2023  1734702816365584465
# 704  Tue Dec 12 22:32:33 +0000 2023  1734702806727037337
# 705  Tue Dec 12 22:32:27 +0000 2023  1734702785428385865
# 706  Tue Dec 12 22:32:21 +0000 2023  1734702756848427375
#
#                                              full_text  quote_count  \
# 0    Mendingan bully emyu yg goblok dah daripada ri...            0
# 1    @NgalimanMS @aniesbaswedan @cakimiNOW @DPP_PKB...            0
# 2    mulai goyah abis nonton debat capres :";0;1;0;...            0
# ...
